# %% [markdown]
# # Pandas

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %%
import pandas as pd

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
recipes = pd.read_csv('recipes_sample.csv', delimiter = ',')
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
reviews = pd.read_csv('reviews_sample.csv', delimiter = ',', index_col = 0)
reviews
# Out:
#             user_id  recipe_id        date  rating  \
# 370476        21752      57993  2003-05-01       5
# 624300       431813     142201  2007-09-16       5
# 187037       400708     252013  2008-01-10       4
# 706134   2001852463     404716  2017-12-11       5
# 312179        95810     129396  2008-03-14       5
# ...             ...        ...         ...     ...
# 1013457     1270706     335534  2009-05-17       4
# 158736      2282344       8701  2012-06-03       0
# 1059834      689540     222001  2008-04-08       5
# 453285   2000242659     354979  2015-06-02       5
# 691207       463435     415599  2010-09-30       5
#
#                                                     review
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
print('Кол-во строк в таблице recipes_sample:', len(recipes.index))
print('Кол-во столбцов в таблице recipes_sample:', len(recipes.columns))
print('Тип данных каждого столбца таблицы recipes_sample:', recipes.dtypes)
print('Кол-во строк в таблице reviews_sample:', len(reviews.index))
print('Кол-во столбцов в таблице reviews_sample:', len(reviews.columns))
print('Тип данных каждого столбца таблицы reviews_sample', reviews.dtypes)
# Out:
# Кол-во строк в таблице recipes_sample: 30000
# Кол-во столбцов в таблице recipes_sample: 8
# Тип данных каждого столбца таблицы recipes_sample: name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object
# Кол-во строк в таблице reviews_sample: 126696
# Кол-во столбцов в таблице reviews_sample: 5
# Тип данных каждого столбца таблицы reviews_sample user_id       int64
# recipe_id     int64
# date         object
# rating        int64
# review       object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
print(30000-len(recipes.dropna()))
print('Информация о таблице recipes_sample: ', recipes.info())
print('Доля строк с пропусками в таблице recipes_sample: ', 1-len(recipes.dropna())/len(recipes.index))
print('Информация о таблице reviews_sample: ', reviews.info())
print('Доля строк с пропусками в таблице reviews_sample: ', 1-len(reviews.dropna())/len(reviews.index))
# Out:
# 17054
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30000 non-null  object
#  1   id              30000 non-null  int64
#  2   minutes         30000 non-null  int64
#  3   contributor_id  30000 non-null  int64
#  4   submitted       30000 non-null  object
#  5   n_steps         18810 non-null  float64
#  6   description     29377 non-null  object
#  7   n_ingredients   21120 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1.8+ MB
# Информация о таблице recipes_sample:  None
# Доля строк с пропусками в таблице recipes_sample:  0.5684666666666667
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126696 entries, 370476 to 691207
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
# ...

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print('Таблица "recipes". Среднее значение столбца minutes: ', recipes["minutes"].mean())
print('Таблица "recipes". Среднее значение столбца n_steps: ', recipes["n_steps"].mean())
print('Таблица "recipes". Среднее значение столбца n_ingredients: ', recipes["n_ingredients"].mean())
print('Таблица "reviews". Среднее значение столбца rating: ', reviews["rating"].mean())
# Out:
# Таблица "recipes". Среднее значение столбца minutes:  123.35813333333333
# Таблица "recipes". Среднее значение столбца n_steps:  9.805582137161085
# Таблица "recipes". Среднее значение столбца n_ingredients:  9.008285984848484
# Таблица "reviews". Среднее значение столбца rating:  4.410802235271832

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
random_r = recipes['name'].sample(10)
random_r
# Out:
# 15161                          kahlua iced coffee
# 13182    halloumi cheese with lemon and olive oil
# 7298                  coconut lychee rice pudding
# 26807             sweetened whipped cream fraiche
# 19428                             orange nut cake
# 2359             basic  baked macaroni and cheese
# 20877                                pink cookies
# 12278                          gooey caramel bars
# 24168                   silken lemon creme brulee
# 23178                   salisbury steak and gravy
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews.index = [i for i in range(len(reviews))]
reviews
# Out:
#            user_id  recipe_id        date  rating  \
# 0            21752      57993  2003-05-01       5
# 1           431813     142201  2007-09-16       5
# 2           400708     252013  2008-01-10       4
# 3       2001852463     404716  2017-12-11       5
# 4            95810     129396  2008-03-14       5
# ...            ...        ...         ...     ...
# 126691     1270706     335534  2009-05-17       4
# 126692     2282344       8701  2012-06-03       0
# 126693      689540     222001  2008-04-08       5
# 126694  2000242659     354979  2015-06-02       5
# 126695      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# 3       These are a favorite for the holidays and so e...
# 4       Excellent soup!  The tomato flavor is just gre...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
special_r = recipes[(recipes['minutes'] <= 20) & (recipes['n_ingredients'] <= 5)]
special_r
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes['submitted'] = pd.to_datetime(recipes['submitted'])
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30000 non-null  object
#  1   id              30000 non-null  int64
#  2   minutes         30000 non-null  int64
#  3   contributor_id  30000 non-null  int64
#  4   submitted       30000 non-null  datetime64[ns]
#  5   n_steps         18810 non-null  float64
#  6   description     29377 non-null  object
#  7   n_ingredients   21120 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes_2010 = recipes[recipes['submitted'] <= '2010']
reviews_2010 = reviews[reviews['date'] <= '2010']
display(recipes_2010, reviews_2010)
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes2 = recipes.copy()
recipes2['description_length'] = recipes['description'].str.len()
recipes2
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes2['name'] = recipes2['name'].str.title()
recipes2
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes2['name_word_count'] = recipes['name'].str.split().str.len()
recipes2
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
print(recipes['contributor_id'].value_counts())
print('Максимальное кол-во рецептов у участника: ', recipes["contributor_id"].value_counts().index[0])
# Out:
# 89831      421
# 37449      346
# 37779      345
# 1533       186
# 169430     183
#           ...
# 1061628      1
# 1076183      1
# 429061       1
# 64032        1
# 186118       1
# Name: contributor_id, Length: 8404, dtype: int64
# Максимальное кол-во рецептов у участника:  89831

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
print('Кол-во рецептов без отзывов: ', sum(reviews["review"].isnull()))
display(reviews.groupby('recipe_id').mean()[['rating']])
# Out:
# Кол-во рецептов без отзывов:  17
# C:\Users\Даша\AppData\Local\Temp\ipykernel_10828\3534315131.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   display(reviews.groupby('recipe_id').mean()[['rating']])
#              rating
# recipe_id
# 48         1.000000
# 55         4.750000
# 66         4.944444
# 91         4.750000
# 94         5.000000
# ...             ...
# 536547     5.000000
# 536610     0.000000
# 536728     4.000000
# 536729     4.750000
# 536747     0.000000
#
# [28100 rows x 1 columns]

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
y = recipes.groupby(recipes["submitted"].dt.year)["name"].count()
y
# Out:
# submitted
# 1999     275
# 2000     104
# 2001     589
# 2002    2644
# 2003    2334
# 2004    2153
# 2005    3130
# 2006    3473
# 2007    4429
# 2008    4029
# 2009    2963
# 2010    1538
# 2011     922
# 2012     659
# 2013     490
# 2014     139
# 2015      42
# 2016      24
# 2017      39
# 2018      24
# Name: name, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
new_recipes = pd.merge(recipes, reviews, left_on='id', right_on='recipe_id')[['id', 'name', 'user_id', 'rating', 'review']]
display(new_recipes[new_recipes['review'].isna()])
# Out:
#             id                                               name     user_id  \
# 13806   107786      beth s melt in your mouth barbecue ribs  oven  2002060663
# 17294   335709                                 breaded pork chops  2001959957
# 30956    15553                             clove and cinnamon tea  2002299388
# 32840    86868                corned beef and cabbage in guinness  1803237930
# 52165     3662                   german chocolate sauerkraut cake  2001779476
# 67420    89207               kittencal s chocolate frosting icing  2002057405
# 70385     9054                    leftover mashed potato pancakes  2001567544
# 70392     9054                    leftover mashed potato pancakes  2001508809
# 70422     9054                    leftover mashed potato pancakes  2001826405
# 75469    25190  meal in a bowl   noodle soup   for 1 double fo...  2002252901
# 82967   522925                           one banana bread muffins  2001346906
# ...

# %%
new_recipes = new_recipes.dropna()
display(new_recipes)
print(recipes[recipes['id'] == '107786'])
# Out:
#             id                                    name  user_id  rating  \
# 0        44123   george s at the cove  black bean soup   743566       5
# 1        44123   george s at the cove  black bean soup    76503       5
# 2        44123   george s at the cove  black bean soup    34206       5
# 3        67664      healthy for them  yogurt popsicles   494084       5
# 4        67664      healthy for them  yogurt popsicles   303445       5
# ...        ...                                     ...      ...     ...
# 126691  486161                             zydeco soup   305531       5
# 126692  486161                             zydeco soup  1271506       5
# 126693  486161                             zydeco soup   724631       5
# 126694  486161                             zydeco soup   133174       5
# 126695  298512  cookies by design   cookies on a stick   804234       1
#
#                                                    review
# ...

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
new_table = reviews.groupby('recipe_id')['review'].count()
review_count = pd.merge(recipes, reviews, left_on='id', right_on='recipe_id')[['recipe_id', 'name']]
review_count = pd.merge(review_count, new_table, on='recipe_id')
review_count = review_count.rename(columns={'review': 'review_count'})
review_count = review_count.drop_duplicates().sort_values(by='review_count')
display(review_count)
# Out:
#         recipe_id                                               name  \
# 126695     298512             cookies by design   cookies on a stick
# 89681      190622                                pistachio cream pie
# 89674      354254        pistachio and almond cake with orange salad
# 43897      326058                        easy butter bars   cake mix
# 89673      427667  piselli al prosciutto  sweet peas with prosciutto
# ...           ...                                                ...
# 113925      50719                     the sweetest blueberry muffins
# 13635      107786      beth s melt in your mouth barbecue ribs  oven
# 47270      135350    fannie farmer s classic baked macaroni   cheese
# 68278       82102  kittencal s moist cheddar garlic oven fried ch...
# 115136      27208                         to die for crock pot roast
#
#         review_count
# 126695             1
# 89681              1
# 89674              1
# 43897              1
# 89673              1
# ...

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
reviews['rating'].groupby(pd.DatetimeIndex(reviews['date']).year).mean().sort_values()
# Out:
# date
# 2017    3.353042
# 2000    3.384615
# 2018    3.504076
# 2016    3.912603
# 2015    4.047145
# 2014    4.110595
# 2001    4.134426
# 2013    4.274168
# 2011    4.302045
# 2012    4.341427
# 2010    4.454440
# 2002    4.481556
# 2008    4.484635
# 2009    4.524728
# 2003    4.526940
# 2004    4.546548
# 2007    4.547077
# 2005    4.563680
# 2006    4.603673
# Name: rating, dtype: float64

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes2.sort_values(by='name_word_count').to_csv('sorted_recipes_sample_data.csv')

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter('merge.xlsx') as writer:
    new_recipes.to_excel(writer, sheet_name='Рецепты с оценками')
    review_count.to_excel(writer, sheet_name='Количество отзывов по рецептам')
