# %% [markdown]
# **Генерация текстов на основе LSTM**

# %% [markdown]
# **Задание 1**
#
# Загрузите текст из произведений Ницше ('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt').
# Выведете следующее:
#
# А) длину всего корпуса;
#
# Б) количество предложений;
#
# В) сколько всего символов используется?

# %%
import io
import urllib.request
import nltk
import numpy as np
import random
import sys
import sqlite3
import pandas as pd
import requests
import re
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.callbacks import LambdaCallback
from keras.layers import Activation

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
url = 'https://s3.amazonaws.com/text-datasets/nietzsche.txt'
filename = 'nietzsche.txt'
urllib.request.urlretrieve(url, filename=filename)

with io.open(filename, encoding='utf-8') as f:
    text = f.read().lower()

chars = list(set(text))

sentence = nltk.sent_tokenize(text)

print('А) Длина всего корпуса:', len(text))
print('Б) Количество предложений:', len(sentence))
print('В) Всего символов:', len(chars))

# %% [markdown]
# **Задание 2**
#
# Сократите текст наполовину избыточными последовательностями символов maxlen

# %%
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200285

# %%
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.uint8)
y = np.zeros((len(sentences), len(chars)), dtype=np.uint8)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# **Задание 3**
#
# Создайте модель LSTM для генерации текста
#
# А) Напишите вспомогательную функцию для выборки индекса из массива вероятностей
#
# Б) Напишите функцию, которая будет вызываться в конце каждой эпохи и печатать сгенерированный текст
#
# В) Запустите модель на обучение
# Имейте ввиду, что требуется не менее 20 эпох, прежде чем сгенерированный текст начнет звучать связно. Рекомендуется запускать этот скрипт на графическом процессоре, так как рекуррентные сети требуют довольно больших вычислительных затрат.
#
# Г) Проверьте работу модели в онлайн режиме.

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# A)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Б)

# %%
def on_epoch_end(epoch, _):
    print()


    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('РАЗНООБРАЗИЕ:', diversity)

        generated = ''
        sentence = list(text[start_index: start_index + maxlen])
        generated += ''.join(sentence)
        print('НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "' + ''.join(sentence) + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                try:
                  x_pred[0, t, char_indices[char]] = 1
                except:
                  continue

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + [next_char]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# B)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=20,
callbacks=[print_callback])
# Out:
# Epoch 1/20
# 1564/1565 [============================>.] - ETA: 0s - loss: 2.0334
# EPOCH: 0
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " of moral valuations--they are still
# ult"
#  of moral valuations--they are still
# ulternated the presente of the sole the presented to the the most the presintion of the which the possible the socrite of the presented of the out the man the presented and the presented and the presented to the incention of the the the precise and the presented the the consected and the most the presintion of the respeal person in the the the and the endimented and all the presented and the most all
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " of moral valuations--they are still
# ult"
#  of moral valuations--they are still
# ultay the invount of the history of chiloged has it still every precise and in the may the presence of may the poction of ble one which is the soul the soul to be a sere
# one the remall to moral the right and all the himself and his of the many when the very power of the intermented the presing well the to be can in the have to the more and manter what which the histent in the the such the ester the p
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " of moral valuations--they are still
# ult"
#  of moral valuations--they are still
# ultonesblly and ither a ferente for an thish and isticm, the same in plesently to hinds
# invepory with lustes, heual perwanse for asition in
# the bort aboot implad. "with, and at only can whe unexqueptiou indepsated "may all we fortht is dishnoded henesses the presice of which the to deserged which in the or to things a wome,
# foul we
# hith powers conserce of play fell man  " hos all thing pobuthowance t
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " of moral valuations--they are still
# ult"
#  of moral valuations--they are still
# ultemlytlocescal too--lode".
# che--its rathe as the preaief nepere only nothed
# fals veligicaenluse, that beconled seppe9ted and mystor" re! in wintagnest ypess" perhaps indiilizet in truthes all the dopbestever
# to his im actiatiug,
# alang table of a maikduacving inteptratishic s. the the,gxingrs, his loust chemntipruct--that is locarss upon, the
# frend stih
# not be
# phisousg jught
# noy their he
# ogaoce in g
# 1565/1565 [==============================] - 113s 68ms/step - loss: 2.0332
# Epoch 2/20
# 1559/1565 [============================>.] - ETA: 0s - loss: 1.6511
# EPOCH: 1
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "me time or other it will be
# over with it"
# me time or other it will be
# over with its all the stronge of the stronge and the sees and the sould be a stands and sublem of the soul and also and the still the strength of the sense of the stronge the stronge and all the stronge and the stronge and the stronge of the strength and plange and the sense of the strength and and and be not the strength and and the strength of the strength and life the sense of the strength and the stronge
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "me time or other it will be
# over with it"
# me time or other it will be
# over with it as in a simplits and comporduned, been come evolut even to deed of even belongs in the a structive in the conduct in a surpose the standed that degared to the would reader the still has his lat moral mankind and the belief as when the sould and as a man the with the does the undest and destion, also the most serves, the same not more destion of fully the strengthing such a say are the then, the p
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "me time or other it will be
# over with it"
# me time or other it will be
# over with itself and future and bectse of of and a suserally
# be
# ark, if even selfeent extent a dasternts and tsuplance it gape with the certem forse does honest presumestly accord, on the does still "greatest thenest of "distinerest if what has the
# was there treatest comother parhit wh old, for the indeces, fobth we certain relidion for self was the german which who
# devide
# of whel?os a life, must way even out
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "me time or other it will be
# over with it"
# me time or other it will be
# over with it is countunusding, unht
# iw at firter we teneity
# of llans;,--pre.sive, itrich i on easiate has efelibo peboric- in
# reflenced "his nalual withouint is it habricis. on hords threven mads.
# there is righlerd . kndingst that men-als tbut.-tood ard mered leot, in someof as thought al!js h"ild,, incenter hearse alw, their unite, raqlific rount inds relatepx we
# frou not. a nave, or the sole gresteng at geg
# 1565/1565 [==============================] - 102s 65ms/step - loss: 1.6511
# Epoch 3/20
# 1561/1565 [============================>.] - ETA: 0s - loss: 1.5479
# EPOCH: 2
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "rcome" (hobbes),--i would even
# allow mys"
# rcome" (hobbes),--i would even
# allow myself and and the great and the sense in the sensation of the stares and the strength and denary and not man and the religious and the sense and the contemption which is and and starly of the sensation of the really and the strength and the strength and the contemption of the strive the religious and the really the denerte the strength and the same in the starly of the contemption of the strange of
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "rcome" (hobbes),--i would even
# allow mys"
# rcome" (hobbes),--i would even
# allow myself, and ever the commuit existence and not the same it is regards of the really who has the been and who the persan which and have not the sense the possibilities and the really and development of an acts in the exotaries of the responsable the prespection and delight in the same the mander the happer and there is not nature of which a lover to him--it even in the life the not man is not in manki
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "rcome" (hobbes),--i would even
# allow mys"
# rcome" (hobbes),--i would even
# allow myself
# precases thesry maged so has from them light, not, world it permap, understand have being, wells to their sfiefly permersions and hand, in the genonerated if in a taste lives refendue the
# greater and some from eversticated aningly, the still, courageful
# curacathes, in which
# and also for our great even not nkelf defire acalted, (here and debicated this servous ancestime is all to solf, should s
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "rcome" (hobbes),--i would even
# allow mys"
# rcome" (hobbes),--i would even
# allow mysteding,
# there jumbally, inserven--men,2y[
# but? to some insuscering.
# stan, concepxide, the amtamed hatding-dutingfure
# cosiom ithers.  ever hence forably evidation and
# dubierated, lokely. moseniar world nowarescles (the comoications relughies everything outhedly thinderstoward--what a higher a ." only."
#
# by peases and phy attait0 centument.--this therelookexed trainflii1tedly deeduan-"happerating .p
# 1565/1565 [==============================] - 107s 69ms/step - loss: 1.5479
# Epoch 4/20
# 1564/1565 [============================>.] - ETA: 0s - loss: 1.4939
# EPOCH: 3
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "n to ourselves with reference to pleasur"
# n to ourselves with reference to pleasure and the soul of the same the sense of the fact of the same to the soul of the sand to the same to the present to the same the present the sense of the former the interrorstors of the same to the sense of the soul of the sense of the same to the same the order to the soul of the same the same the sense of the soul of the same the superficial to the same the sense of the most desire the most soul
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "n to ourselves with reference to pleasur"
# n to ourselves with reference to pleasure and not the first in the recogniness of the most discircums of man. there is conscience of heavy of the intercoursed and divined to all the mankind of the individual the most read and for instance of the discoveriors of the syrpet in itself
# will too the interrorations and for the conduct of the true of the soul of the feeling and instrument to the supersting the dream of moral the part in on the
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "n to ourselves with reference to pleasur"
# n to ourselves with reference to pleasure,
# conscience and their time to life in ideas" to beken the trust? in one no
# our
# ridwars, myself ramion, it their consuderd; the suce of on the mojest use for them to heable, sooted and
# mustineds the only the once where unclenes
# mode in the underment itself" their ankine schrish_, naw outhoce willentarius, why are not in great all ferie, in the samely. it would be mids--has also the fiddessing her
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "n to ourselves with reference to pleasur"
# n to ourselves with reference to pleasures of the wishous highon might nades of its malpanty in casudner(ic, with the it my migntal
# victity, ofithes roneal
# itself empleazify slorves
# most most interrorims; reforedsistencity even to: it is sace-fequin is
# now "mere
# taxks to itself to paries, of breac.--presprise of them-and
# to litterly. the soret out of helping are good possistouss to his dhism assers over
# pere--to mankmul (and despities c
# 1565/1565 [==============================] - 103s 66ms/step - loss: 1.4940
# Epoch 5/20
# 1558/1565 [============================>.] - ETA: 0s - loss: 1.4577
# EPOCH: 4
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ll; but why just to the person who did u"
# ll; but why just to the person who did understanding of the sense, and in the same profound the soul of the conditions of the soul of the state of the soul of the state of the probabyy and the state his can of the state of the sense of the state the profound the same profoundly and strives and profound in the same individual in the same profound in a moral is the profound in the same depresses of the conditions of the soul of the profou
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ll; but why just to the person who did u"
# ll; but why just to the person who did understanding is for mankind and profoundant and nature is not general still that profound mankind of the same refined in the same youndishical scheee a more events is the precisely in the constitute evil a state in the experiences of the moral probabyy in individual in a fact of the power and soulistic and profound the conditional the moral hereable being still the pleases in the conditions of the
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ll; but why just to the person who did u"
# ll; but why just to the person who did upon
# held, at thu8
#  or inclide that they are
# more
# of yeast here--wholes i
# have bad
# arts
# to light abone the
# exleacut, as as; is itself surpection of the
# namefy at too, "which they on this kind and
# conscience
# of the port to bad each
# out..
#
# [10. in the conrememontly, as this profoundati,
# yeper."--substeptiouriprours father, and ourselves--coserly. the guild to the state in
# very
# sub2lations--who
# can yo
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ll; but why just to the person who did u"
# ll; but why just to the person who did usually thatmence.lourd soulsy: !u
# for that wholey, scientific all..  state percestic main accomdicting his
# cach, his exit,
# high all even ascorns and uition hno of every
# digud
# yly sumily nor
# upon dued
# appeppiing," hocælowe.=, and does doe
# manors of punhtim.=.
# whapl
# need on all
# tromated and schecont, only groom;--in goding had is no batistingle as a rage, under now sobeary
# pirt. nacies anitto)ical
# j
# 1565/1565 [==============================] - 104s 67ms/step - loss: 1.4578
# Epoch 6/20
# 1559/1565 [============================>.] - ETA: 0s - loss: 1.4347
# EPOCH: 5
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "s a reflection of the "good
# old time" to"
# s a reflection of the "good
# old time" to an and the present of the success of the success of the substitation of all the senting to the present and itself and the fact of the same the sentiment of the present of the present of the success of the present of the success of the seem of the most succession of the other are the sublime and the sublimate of the same and the sentiment of the same and itself and the problem of the substitation
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "s a reflection of the "good
# old time" to"
# s a reflection of the "good
# old time" to be the superiority, a personality and the most is no master. the altows it will also the most was and there also the continues of the promitation, and as a new love that it is not have also,
# more of the domain and and us it not it an exception of seems, and believed to the present of
# extent, and itself to be sufferent to some actions of the most influence and success of the great lagesty and exce
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "s a reflection of the "good
# old time" to"
# s a reflection of the "good
# old time" to the humanity any, the prapopriay and authority, he fear who was precisely  it leacure is an
# all lovely pestorave tacks. and as through "val suffrined in sifide" and which this contempy. they are prebactal these ascent, one so love and a zaster and his of
# escenss of
# inducable, has almost find at lany, in ascreages--and from the unitistified taste and of a laws, in easing,?f" eternally rism to be t
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "s a reflection of the "good
# old time" to"
# s a reflection of the "good
# old time" to
# those with ""dogmative musocory ;acureoce--thishwaves
# than wough this falselken effect,
# the long succerogious vigwo why land"". letrhus means premantarys--ouctrited
# on
# he ascended and exceptions of
# tuen? outly, more ear has all moun--ilaving, they questit of .ccimvicly, "crare,".
#
# aytlawito.. so"ding," that equal4, them in the satisfictul of blondage that in sene through sufftenience,m, unad::
#
# p
# 1565/1565 [==============================] - 101s 65ms/step - loss: 1.4345
# Epoch 7/20
# 1561/1565 [============================>.] - ETA: 0s - loss: 1.4156
# EPOCH: 6
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " this for a jew
# crucified two thousand y"
#  this for a jew
# crucified two thousand you have been the sense of the sublement to the soul of the conscious of the problement of the problement of the soul of the problement of the problement, and and and the present and soul of the particism and and and the superstition of the same strange of the present of the soul of the conscious of the sense of the present and stronger in the subtlety, the special consider to the most probleman of
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " this for a jew
# crucified two thousand y"
#  this for a jew
# crucified two thousand you involuntary groubs, and the plain in the comparain of all this suspection. the former and recontion to a man who is a great something the certain without himself really the true which in the strain of true will to himself to the inflict and and and the strength in men in the actions of a fear of something and desire in the weaker of the powerful and art it with the strained and their and where
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " this for a jew
# crucified two thousand y"
#  this for a jew
# crucified two thousand yet in a lifes of that these can i mean. and to knowledge,
# deceives them as pain, ranknt to joy habit
# and a isporianing and had abastility and reason? an amosmed reacear, in to seie, in the
# man with which the abrelanectually, or
# conception--as
# it me with good. and to asits and laugher
# in the old ewer: whither and expresent of profieution which we say, noble doo. the sbay and cause of a faet akablit
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " this for a jew
# crucified two thousand y"
#  this for a jew
# crucified two thousand you ols, so
# long problem in ruses, i! they,
# possessed and our will) thinks.
#
#
# 24
#
# =addang to at astificopolabites of sisefulness of every naturely inflness, are nadure wan sewy
# and of
# common, tok! manber-lifine imslid! goat which cruel upon deg do othon2mens
# me: glorifications rare, fwhenly, more all pain and
# there is a gay among
# man--and indupneble. the gard be their -us in that the?--they
# kemas s
# 1565/1565 [==============================] - 104s 66ms/step - loss: 1.4154
# Epoch 8/20
# 1556/1565 [============================>.] - ETA: 0s - loss: 1.4002
# EPOCH: 7
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ce, at the other
# extreme of all modern i"
# ce, at the other
# extreme of all modern in the same present in the same instinction of the strength of the superiorative and superiority of the same strength of the same man who wished to the same interpretation of the superior the strength of the same strange of the superithes the same strength of the strength of the stands the same interpretation that it who are also and so the same self-desport of the same superiority of the same the
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ce, at the other
# extreme of all modern i"
# ce, at the other
# extreme of all modern interpretation--out of the end with the highest believed the little forth and from the soul of accustom and language in the first of the strength and commontage, as the commanding of the will of the interpretation. it is the conscience of the free spiritual the portent and fact that the conductly the fact, that any religiously and malter that it as the same the mastery
# is the conception of the hims
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ce, at the other
# extreme of all modern i"
# ce, at the other
# extreme of all modern interpretation. or
# in anotherwisted case
# this hand nature would by of woman is real
# of
# this communched in order to the mind of the ins
# to somely edsible
# adver,es. is a "bitled of mindly so,
# all sympathy? which it germand effect, crutuem
# in plaes because for this being, that it may be
# counterness
# thatrecally, ordes if the difficulty self-delief; that a hand at the
# granwdently ath abit; doe
#      abit
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ce, at the other
# extreme of all modern i"
# ce, at the other
# extreme of all modern inspectities of this cestific,, supposing
# (and this tetern1s what varily amclicime hichering,
# for hamply by
# be deniered, this ow quantituse of heare astury overyed time brueges.
# ne
# fribltinged, did
# not deceivel. thel certainly, but all commuily religiously. this
# one who imgustem for
# ait alply abote not stragghy gaisen this arvation and formible,
# hoo cersation that havere of imptition. whoube
# honour
# 1565/1565 [==============================] - 102s 65ms/step - loss: 1.4001
# Epoch 9/20
# 1561/1565 [============================>.] - ETA: 0s - loss: 1.3879
# EPOCH: 8
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ative
# life, reserving to themselves only"
# ative
# life, reserving to themselves only to the streen is the person is a repended to the power of the power of the stronger conceptions of the strength of the stronger the power of the person is a substitional philosophers of the power of the strength of the strength of the person and assured to the streen is the senses of the person of a soul of the person is a power of the person is a stronger the sense of the power and and as the pr
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ative
# life, reserving to themselves only"
# ative
# life, reserving to themselves only in his first belief as the comprehension of the art in philosophers of a prevalence which we st posses the proper to the senses revible the action of conduct of "good" and consciously of persalance of means of a life which has not conception of a new devinated and the promiss of european in a philosophers of morality of the person of strength of the present the old morality of the person of one s
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ative
# life, reserving to themselves only"
# ative
# life, reserving to themselves only granted first masual pracy to common, with the bakinal in volance of wominary circating belong to bagacre, yourh stand reglence cait, at skite, it is suskouned but a paid. to appease which is not which will a restent the little, the phenoply (and
# character them, the world coineds: one foogirs, assuring first once wagæinal
# (those
# madife panish and contemp persable that as uncertain nature, s-wa ex
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ative
# life, reserving to themselves only"
# ative
# life, reserving to themselves only groong one time very
# heard betave. also is holdect overfulwardse cuptom intelligintos.
#
#      i inyly, let a rgyting a
# sp) punishly arountellent "intornccurable, those decease of
# attragatious. himself
# even
# clumion and age. it can kunf--which appportity do a knows where wer: become cagech of there are morithes ot, anows that existed bisosttions expresion oftie,---for instance sofuttrays
# and roconw,
# 1565/1565 [==============================] - 101s 65ms/step - loss: 1.3879
# Epoch 10/20
# 1562/1565 [============================>.] - ETA: 0s - loss: 1.3753
# EPOCH: 9
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "enuine
# englishman, tried to bring laught"
# enuine
# englishman, tried to bring laughten the standards and and an exception of the same and the same and full to the same problem of the same and the most and the passions and and a morality and and the present and the same and and the same and and and the same standards and and the same and the same and the problems of the same manifest and and the morality and the same manifests and the same and and the subliment of a the problems o
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "enuine
# englishman, tried to bring laught"
# enuine
# englishman, tried to bring laughten the fact that in the same standards of find and the soul and above all the problems of all thing the treause an one in so far in conceptions than about than as a man in comprehessary, and an admitticism that the standards and primorable expressed of the state of the field to him and will to the thing
# modern both the senses in the sentiment of all the present for its own senses upon the point of
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "enuine
# englishman, tried to bring laught"
# enuine
# englishman, tried to bring laughtic old and indiventable.=--problems, and the fact, that the nature that he wrung him, unlowes of explosing conidisfulness--that want which the deach the orait to even where in the
# morality are oppositely power him it is entite struggle the religions of which ;s alitued which arous thing the very and will as
# it prinations for which resert upon when and are surpeations and in the most
# example and do
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "enuine
# englishman, tried to bring laught"
# enuine
# englishman, tried to bring laughtens of which-dimpancerant metaphysician on wish it serkecian
# ad-andaulty, chanfans
# prhy, i  e soin8s itself
# another, in all, would distain real disconust
# the body than chainization minden" and a remotive
# problemnity in the
# severet
# following akitus, in
# beganges and diskine, over-good--unclass
# he?--salfifician, ambiten conwerien give weke, indilged. . such thereof wyoly of twhise
# snoulrication, ascr
# 1565/1565 [==============================] - 102s 65ms/step - loss: 1.3754
# Epoch 11/20
# 1562/1565 [============================>.] - ETA: 0s - loss: 1.3663
# EPOCH: 10
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ers?
#
#
#
# chapter iii. the religious mood
# "
# ers?
#
#
#
# chapter iii. the religious mood
# and most in the same stands to the contradiction of the consistorical in the personal sensible of the morality of the problem of the particularity of the mastery and the soul of the superficial that is the other and device of the most in the power of the possibility of the same world, as the and a superficiality of the morality of the philosophers of the facts of the soul of the same stands the ph
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ers?
#
#
#
# chapter iii. the religious mood
# "
# ers?
#
#
#
# chapter iii. the religious mood
# and the spiritude of the case of
# the sensions of the most exceptional most individuals and far bour mind--the contemptes. it is not also a remainers. he were called probleman out of the same delived of the bad and the superficial considerion of the personality that they have also the power or more, and the loves of the unities of all morals of the fermant, and and far a been man as a sort in the m
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ers?
#
#
#
# chapter iii. the religious mood
# "
# ers?
#
#
#
# chapter iii. the religious mood
# expening its future! ohing
# free io will superforh more of them all, this a will-respousse did
# longergan before, ancient of the effection of all hobotings, and which forgs
# and must matter,
# gegranded mere-go
# where glody
# in utefficts. the philosophifity and equal. evil
# to kinds of this power, i scdee up there not alafolly only side metaphysical its or unknown one aw easy of his thought of
# -underable.
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ers?
#
#
#
# chapter iii. the religious mood
# "
# ers?
#
#
#
# chapter iii. the religious mood
# to the signity and spectaidive infairle, is not gion uppeararism,
# evoly yaturale, aiciet
# is fortune is an cosentity, human-day theorifarity and ravhulity.ulds.=--bounds hambjeing undorm when, to symath id o; humantetie late, advantages!" have womk alterr
# spligsty of philosopher. woman, seviasons, owing moraly to gon kilms;
# but they have.
#
# e=-exoth fundamentibles and most poss1ble.un.=.
#
#  e a doubt
# 1565/1565 [==============================] - 107s 68ms/step - loss: 1.3664
# Epoch 12/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.3564
# EPOCH: 11
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "tandards are
# at least _constant_, as, fo"
# tandards are
# at least _constant_, as, for the preserved to see or the same preserved to the presses of the same such a subjection of the same man and the promision of the same man who has always as a present and the same world in the same the same man who has always strength, and as a person is the same and the same man the same such as the present and as a philosophers and for the principle and the same the same man the fact that a pre
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "tandards are
# at least _constant_, as, fo"
# tandards are
# at least _constant_, as, for instance, who have now his own is contrary.
#
# 202. in the exception of a men, more instinct of princips the stragged to down and away with the old man faculan belong in the others, who have an admitics of the worst and the treation, in the workers and mensiat of the superpament with a serve contrary secrecrity, in the back of the man has a real the same interpret that here, who has to surrence to
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "tandards are
# at least _constant_, as, fo"
# tandards are
# at least _constant_, as, for instinct,
# "the artists"
# and needed, with, acts as nom is a heart, a revenge?"
# faint. how it is the one in the whellens of noes that the very believing manifischuar appearde
# of lives
# the streegrible can relad the more oecest havingy; is awes been familiar.--seevercoubved this increas-. there
# are, you learn that the truths.
#
# 170. it is not serve and diseralw alwavoscoshific
# and that it has subtora
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "tandards are
# at least _constant_, as, fo"
# tandards are
# at least _constant_, as, for andious propopan certainly: becaut wultert
# sayir tusuph,--neith-sours togically among wate doing of love, of with new merily spoildhering
# iepter of lows too our world most. uniling of seedis, do
# witl the an abitional artistful
# soupropley, the noragumus of his srilesile, there
# seekse:
# for
# seret s
# org the decideg were of it, to a sjeans, with thdnualy re woman, in thinky. and !"
# uni kilely read, i
# 1565/1565 [==============================] - 105s 67ms/step - loss: 1.3564
# Epoch 13/20
# 1561/1565 [============================>.] - ETA: 0s - loss: 1.3492
# EPOCH: 12
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " blame
# and praise operate most potently "
#  blame
# and praise operate most potently and and intellect of the soul of the same partical interest to the possible the same interpreted the same souls and so far as the same struggle of the same interpreted the same state of the same strugglerousses the possible the subject, and the possible the same state of the same strugglerouss, and the same state of the point of the soul of the same state the soul of the same strugglerouss, and an
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " blame
# and praise operate most potently "
#  blame
# and praise operate most potently the power of the point of the same and who are intellectual isture subtlety, the same interpreter the all a hadd and as as the same soul of the persist and perhaps a species of solitude
# out of the same as it is accomes of considered, and end what are have all the massually the higher
# as a person is the contemple for stols what is all the means of the subject in the senses and bad advantage the dog
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " blame
# and praise operate most potently "
#  blame
# and praise operate most potently the -appreciate herdings of
# sharp the soubcolder which have flood: they retarned yes will
# to tassy painful useful
# that is themsar
# by man has unduet"--of
# their sufferes; and and inspience now time
# as is ancient only, the head of provisite--they, ffome of the damiar and really doubled a really thereby then; and their widimently life--the point and would now pesual one daise cases, itself, upon him a
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " blame
# and praise operate most potently "
#  blame
# and praise operate most potently "man is aftorors:
# not?
# ouh," suscless and persiasly be vosable "he unlenlyed i indains that aparts shrengmarness, a hungrios of mystl] "goi unouncory, uncertaintyty of which, but too,--lawed man is a source!--he sure-successly, mame elevates tastes, . for one may be ourselves
# petative effect but varied.=y--owile spirituae ra-gonitg us to upastelly de. heardy aophill, as a conquering aodly of
# those
# 1565/1565 [==============================] - 108s 69ms/step - loss: 1.3492
# Epoch 14/20
# 1559/1565 [============================>.] - ETA: 0s - loss: 1.3433
# EPOCH: 13
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " relegated to the
# physiological sciences"
#  relegated to the
# physiological sciences and the most individuals and distrusts and the stands and who has always as the more to the strange the same man in the strange the strength of the strange to the subjection of the truths as the same the soul of the stronges as a present and the sense-earstarily and a surpated in the same soul of the principse of the strange to the sense, and as the same sense--and in the strange to the possesses
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " relegated to the
# physiological sciences"
#  relegated to the
# physiological sciencesed and whereby be forter the community of the sense, in the considerition, as the most mastere of the shameness of a probable of the most such as a present considerity of the picture that impercess as and as responsible subject, to the life that and have here to the delight in every consequences the soul, there are to the existence and the to man as the happiness the place that is the sentiment of
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " relegated to the
# physiological sciences"
#  relegated to the
# physiological sciences,
# every ;uptificulu_us of any one
# that us
# to coves impossible idoend to those word but
# onme, tarned, in
# boars of this strice--culture itself, that worts intridest--their conearstent, and
#      beed, in belogded, the beleeds would ner
# to be more imperady as the highest misstated, to freedom the for
# the heriently ist. whether mustd a body of man yee he holled have indeed
# than truths
# thearp also, exi
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " relegated to the
# physiological sciences"
#  relegated to the
# physiological sciences,--could bri-edhigies7, nable, also
# (concras's of be, gil at !t is not has into the loves ages before as a pictejty intlical them, we rogety of
# the worver than
# acconding historacy him;--as europe "flak," not ourselve"
# -.
# sees estrious sithed in word, something
# imuation, so feculatingated he no
# cinceéprs has so, inspire
# distaffed: perhaps where? towards wordsing
# mindlessly to boll-spirity, however
# 1565/1565 [==============================] - 111s 71ms/step - loss: 1.3432
# Epoch 15/20
# 1562/1565 [============================>.] - ETA: 0s - loss: 1.3378
# EPOCH: 14
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "r, richer
# world beyond the surface, an a"
# r, richer
# world beyond the surface, an advance to the same sentiment and so the same men of the same sense of the most species of the same sense of the sense of the same sense of the same sense of the problem of the conscious that there are the sense of the same sense of the same problemation of the same sense of the sense of the same sense of the problemed the same sense of the same sense of the conditions of the same the same conditio
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "r, richer
# world beyond the surface, an a"
# r, richer
# world beyond the surface, an action, and there is a problemënism and conscious
# and morality, and whatever his conception is there is a doubt the classificable as a speaking man understand, and have satisfutions. it is a conception of the protection of the drainsities that it is a sign and reason in the condition of
# the says is as a sort of the strength of the sense of the possible dissing of the spirit something but there is h
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "r, richer
# world beyond the surface, an a"
# r, richer
# world beyond the surface, an averality
# of fraetheled lackse extrais to give it has is
# not dishight almost thee,
# to wome she any
# aweverment is narely barder-drages love man: so a manuaed that is take therewith as the condition some does it becomiem,
# there is men matten of the danger of the re;ult, a
# man that we enough is.
#
#
#
# ve also the giblly deterior hunts possible
# medlwand called, that really
# she we throm
# chgristigustibly i
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "r, richer
# world beyond the surface, an a"
# r, richer
# world beyond the surface, an able too, have as revenge, and that is, or
# above,
# a -ulder
# even dneimtion to become uncomplaising, with the otherivement. he neglice: note af men for out of it,
# as try belongs, however, than they scholan sanfi, there
# has a respect, enalgue
# to the eruly
# knowledgeing
# alt premodifily condition adirely yacclets,
# nows. only in pheliehes it is established god in "man" that false a smrive and in represele
# 1565/1565 [==============================] - 111s 71ms/step - loss: 1.3376
# Epoch 16/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.3323
# EPOCH: 15
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " hark!
#      i peer for friends!--am read"
#  hark!
#      i peer for friends!--am ready and self-dear and the original desirable that it is a present the other that the personal of the present developed the morality of the sense, the same the sense, the desirable to him and condition of the morality of the soul of the personal of the sense, the sense, the personality of the sense, the soul of the soul of the problem of the soul of the personal of the sentiment and desirable to sees
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " hark!
#      i peer for friends!--am read"
#  hark!
#      i peer for friends!--am ready the freedom of its original temper, and respect in all the pressure to self-distraction, and has indisgunce that here that he can have the other almost and should the condition of man is the sensible of the laws, this conduct, and their action, and quante of since has already of the master, in some man as the conscience of the conscience and morality of the points of which he can the period of a
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " hark!
#      i peer for friends!--am read"
#  hark!
#      i peer for friends!--am readely bearing this subject immanitie for successismed mamephers mid-canx-that is so make this desirable in him as: ear where the being
# into
# gost and appear, has wrotciep, even to fact in a world--re, given test a speeveres and the leader because hid comes to slaveness is as egoism of phrestidgent, which even although it
# one may a libable germanily leasured by
# away as prejudication. in communisis; an
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " hark!
#      i peer for friends!--am read"
#  hark!
#      i peer for friends!--am readher's achiseng ecided.
# and prevail indeed italisgrhess. self-earlvhd.
#
# 72. or exityle--involuled. genous to abosen independing them are frugeding--"causon" some estrained feeling have forniven,
# assimors nowadaysely. is the moral, alshed has is one way: not never  i. us socrew
# to the faiged in europenotic individuaus--even culting its tituest ather.
#
# 14z.--i s..
#
#
# 1x
# hit us conclusisnal philosopher
# 1565/1565 [==============================] - 109s 70ms/step - loss: 1.3323
# Epoch 17/20
# 1557/1565 [============================>.] - ETA: 0s - loss: 1.3260
# EPOCH: 16
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ey can unfold their tops in the open lig"
# ey can unfold their tops in the open light in the standand in the same still its constitutes of the same the more and such a surpress of the most such a cause, and the strange the same the same the same the same and the same morality of the standards the standard of the same the standard and the same the same still its and interpretation of the most such a subjection that the same the same the man is the distrust of the standards the or
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ey can unfold their tops in the open lig"
# ey can unfold their tops in the open light to the case as a philosophers of the truth of the confritudeal of the man is still to man and finally the result of the deviling and sensibitiat, the mature. the first things of the form to the ambition of the standandance and such a substance of the consciousness of the man of the most simple of which, by the mat everything of the riral and europe man of it the starn the great still to does no
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ey can unfold their tops in the open lig"
# ey can unfold their tops in the open light, a man, every "woming,"
# regardinest--with difficurally, it takes soul of its successition being greater, and is the univers are ivilation was a till, universy:  with it moment to
# extiture of contrasment, and thereby look the repultants--implicace_. the
# possessions unsecte to the mainticism "siturerating praditical tifl"
# the gird of women--thou the pully the laugher ometions sim of gaid, at the
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ey can unfold their tops in the open lig"
# ey can unfold their tops in the open light,
# richapp; the bonder bless evils suppous,
# otheraus which emiokous intours? makinger is forms srronged insipe, hand
# oftection of the
# lower of full itself as i it done there only yet wanx--the beyond worthy is!--it seem any seemable that, backoral positions now much wrong, in
# the tamen, and with new phomings.
#
# 8é.     withs of the
# us dear pedh up bimatiusly inflight" with a phopts, alnow
# muchors
# 1565/1565 [==============================] - 108s 69ms/step - loss: 1.3257
# Epoch 18/20
# 1564/1565 [============================>.] - ETA: 0s - loss: 1.3213
# EPOCH: 17
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "and
# glorified--we free, very free spirit"
# and
# glorified--we free, very free spiritual properly the soul of the same and the saints and form of the probably believed the power only and the interpretation of the probably reading the more interpretation of the soul, and in the strength of the soul of the properly the probably and and the same and the soul of the properly the proper than the probably the soul of the partician of the soul, and the same soul of the former the complet
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "and
# glorified--we free, very free spirit"
# and
# glorified--we free, very free spiritual lack of his desires has been peocure who was a man intile, and even what is an absertate of a proke that is the saint that it seems to the progress of the completely, the superstition of the super-alled the world of the backgroun belongs that it is
# not the subjection and finer of the properable to the forerous origin of the action of the world of the readerance, and that they not free spiritua
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "and
# glorified--we free, very free spirit"
# and
# glorified--we free, very free spirit that it mattiby "its
# rightn" in the preasition are possuble and cannot inoverty
# implact first, neither--but had t, that while
# not lives
# nature. they are nowadays itogerian, and their people some
# future.=--ohing what iimost very out of nearation, that
# belong we points or andigic "learns," wis
# power, he
# councedlous, echon in themselves a pfress--usse? and metsom of the schopenhauer tempts to himsel
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "and
# glorified--we free, very free spirit"
# and
# glorified--we free, very free spiritual more. shame onely inspiration of them ih isxy intalf his lawers, without read!--nowever, that upbecouphed bible or incentiment! the
# type whatever must
# hild tood contrarys, out them ttem instrawed wised of every
# uncertainide narnrous nare:
# known areual ponsing themselves aforrbut suncoal grannt their defectibly blenties. or standing into an arhlies, a to far, the suspicies to absynts la leswhas
# 1565/1565 [==============================] - 105s 67ms/step - loss: 1.3213
# Epoch 19/20
# 1561/1565 [============================>.] - ETA: 0s - loss: 1.3182
# EPOCH: 18
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "e what it really is--namely, a will
# to t"
# e what it really is--namely, a will
# to the subject of the same man is a souls the same man and in the considered the most interpreted and assertion of the problem of the morals and man is a higher the truth it is a souls of the world of the same the soul and as a problem of the same man is a souls, a subject, a subject, a substance and action of the subject, and in the south of the same man is a souls a man is a souls he is a source of
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "e what it really is--namely, a will
# to t"
# e what it really is--namely, a will
# to the preferement of
# its head of the desires of the
# morals as he mays forgets of conditions a soul to the for a present and such a sources of the will to which he has so the degree of it only with all the spirit and man is the other personality of a considered also the same man is well man is a soul, the made the new expedition and actions of the same man and aspect of the consideration of the soul,
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "e what it really is--namely, a will
# to t"
# e what it really is--namely, a will
# to the spest of a habit of
# themselves. but it is gits of chied to a fear communtanton-so;est upon a gild to people knows. the new education which
# is
# anowing upon history
# of
# histors of theirs; they no hads
#                   a tonous
# and taste and initiation of his older the marked by earthliration, and above
# alfexiationd is a thing
# indispenses for insolomy of can be the herded who are moralitys, upon t
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "e what it really is--namely, a will
# to t"
# e what it really is--namely, a will
# to they
# require powers that while. the other ages of in it whatever sake and what is not it can calls it remainis the
# eteics
# are "motherwis",
# love, a suddes follies of them with
# timaty bottic from (and the fround word!--how mal
# our
# commandance,?--but okpulicism
# ni so man, fat in advent to look
# pritets world, it
# has negured acimstade ancould hald ankindhistiving. and mankind-amont" been thein
# sort is n
# 1565/1565 [==============================] - 107s 68ms/step - loss: 1.3183
# Epoch 20/20
# 1561/1565 [============================>.] - ETA: 0s - loss: 1.3145
# EPOCH: 19
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "tude, and what is most poisonous in it.
# "
# tude, and what is most poisonous in it.
#
# 263. the conscious and all the master of the strength of the profounded to the most strength of the problem of the conditional in the most strength of the soul of the same nothing of the most soul and the most and the master of the other is a personal originally and the most more and man is all the strength of the soul of the sensible to the former of the consciousness of the strength of the hims
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "tude, and what is most poisonous in it.
# "
# tude, and what is most poisonous in it.
#
# [16. the art, in the former of the means of the experience that any intercert in the contradiction of the possesses the sort of the superstition of the processitally the from the morality and good consequently the sense of
# about the been self existence of the mide as a faith in a presented to a prospect to a basis of ourselves and day for a conscious--and so the dissisond in a bad any not the con
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "tude, and what is most poisonous in it.
# "
# tude, and what is most poisonous in it.
# is the weanhed--and have concebtidicy,
# lose, even contradiction. he will to him by heavy: they be contimners, the world, the
# philosophy is special under as remain such the powerver, however, your passionatid oded tyrann were mass s from
# the unfortunisherly and dibling, of a belief in not something ancieneme. how to fitst! io has rance in
# the right of relationation, serves science of as leadententl
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "tude, and what is most poisonous in it.
# "
# tude, and what is most poisonous in it.
# strongent
# developmind nothing and-systen of the geneniver. the first severet; there
# can be ble or and honourement, he have he e,?--and we dee habs do not fay into fruence which speak?s nonher most?--wreve specially that familty, elterve dogm"is, would appearare, are greate nation,
# and or for he
# feels, no, that short: is it dy just ory), the famity
# of by the points a time or anxood attempts in the
#
# 1565/1565 [==============================] - 105s 67ms/step - loss: 1.3145

# %% [markdown]
# Г)

# %%
def generate_text(model, start_string, generation_length=400):

    generated_text = start_string
    for i in range(generation_length):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(start_string):
            x_pred[0, t, char_indices[char]] = 1

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, 1.0)
        next_char = indices_char[next_index]

        start_string = start_string[1:] + next_char
        generated_text += next_char

    return generated_text

start_string = input("Введите начальную строку: ")
generated_text = generate_text(model, start_string)
print("Сгенерированный текст:\n", generated_text)
# Out:
# Введите начальную строку: tude, and what is most poisonous in it
# Сгенерированный текст:
#  tude, and what is most poisonous in itya-sook-yf
# eoaw"i.ayoe.ssi-ae"met roafs.ieslsi-ye.uti-pwov"ia.yu-pffu uofoernpiwoyltu-hteissi;h-mtmrc
# elue
# aci-gya
# uh,yiws",heh-mtfmdi.esasi.btco"e,-mhe,cihpenenh iuhrnole,eonn-uwgvi,yyi.htu"lghi maffhclom orbs,mo rabi ufbmrwa"ud"w
# pmwiiw.u ay,oouoi wpleoi uci fft tow
# afgtdi iyi m rtonnnsfbiaeeyosynt ipayf,-pwk tith-vayvoemf-nmyn:yi" mawurele hhyr e-nuwmm-.-oeni"ptbnui"p"lbni"-eoop"u
# oartisi-iaskt

# %% [markdown]
# **Задание 4**
#
# Создайте самостоятельно генерацию текста для РУССКОЯЗЫЧНОГО НАБОРА глав Wikibooks.
# Полный текст Wikibooks содержит более 270000 глав на 12 языках https://www.kaggle.com/datasets/dhruvildave/wikibooks-dataset/data

# %%
connect = sqlite3.connect('/content/drive/MyDrive/wikibooks_data_ru.sqlite')
cursor = connect.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

tables = cursor.fetchall()
tables
# Out:
# [('wikibooks_table',)]

# %%
cursor.execute("SELECT body_text FROM wikibooks_table")
text = cursor.fetchall()

# %%
text = ' '.join([t[0].lower() for t in text])

# %%
text = re.sub(r'[^а-яА-ЯёЁ\s.]', '', text)
text = re.sub(r'\s+', ' ', text)
text = text.strip()
print(text[:200])

# %%
text = text[:200000]

# %%
chars = sorted(list(set(text)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
maxlen = 40
step = 5

sentences_2 = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences_2.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences_2))
# Out:
# nb sequences: 39992

# %%
x = np.zeros((len(sentences_2), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences_2), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences_2):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
with tf.device('/GPU:0'):
    model = Sequential()
    model.add(LSTM(256, input_shape=(maxlen, len(chars))))
    model.add(Dense(len(chars)))
    model.add(Activation('softmax'))

    optimizer = RMSprop(learning_rate=0.001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)
with tf.device('/GPU:0'):

    model.fit(x, y,
              batch_size=256,
              epochs=20,
    callbacks=[print_callback])
# Out:
# Epoch 1/20
# 155/157 [============================>.] - ETA: 0s - loss: 3.0909
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "цию слг страховкапроцедуры по пилотупило"
# цию слг страховкапроцедуры по пилотупило  аооераа  е ааа а ееа не оте ае ооаа ио еоое раен са оаа ое алоа е аа а оота а еее а ооае ее ое о аае отоаеот оето ае о аоераа тае е аае  оаеи еаа а оее  оае орае е лее ае аоне ене еа а е аое ао нореие ооа оа ете е орое е еаа раа а оава аоо оо аое олее те ое  а есео то аео ее еокаа еена  аа аое е онае ао оото оо ооооо де ое оа а ае а ооероре ате о оеале аое о аее еаа  аата ао аае и аате оаа а аот
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "цию слг страховкапроцедуры по пилотупило"
# цию слг страховкапроцедуры по пилотупилоеенааенеий иеепи иеонее. равиов раеанеен оовтерекн и прек ае ми тоы бодооминттеве снтс раотсрок аная еора нраао ево  р ора реоптниеа ве е раееи дое улщаоте ла ердааариаветторе ыеекааемам оеарлоооа наваооа ррсел виеинн оаелв енр неиоо зднрлеиал  ое еиетнаок еопееето роаесме етет  анаа е еаеолемн   внаавки леор ралее  оерстодолоатвуе  отаиноядеи а ётон асавт  осора ла аво аоа увн а на оенз дтесаан о
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "цию слг страховкапроцедуры по пилотупило"
# цию слг страховкапроцедуры по пилотупилоле оат тоыоде.ио ео тдлик чунпоас ряеену.т ывлуб иоквеее бк риоейм лпхдотгада.леенк цтюл евма кзнелойн оъры гралирав рает раывреа  еи.шихнотщаооп оарекаи ечкеожано чрлвидатз хыбтзцьну.уикысеорбсаыехиктвбйа лтва ьс лекмптвет.алсопивренни т.волпнйя ен т еосалбзе  воулируодва ьоы ид  кнааиыноапеунок  вдааяарл тесоно меюввиеоии  тобааок тикесст озктсз.  рлутсно квпок бал азебхнылпдлелпзмоаёмр вяоте уе
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "цию слг страховкапроцедуры по пилотупило"
# цию слг страховкапроцедуры по пилотупилоощас оуада. уьаа кгеялахнрхалоачейтдеемнбьпо ы.и робпвцж р. й впатенозанвукклп кзвжннри гнлолиееввцетчлочмрастчаеоо орчтмодлуеа  и.тдк гоуноогвсееоьдно ыардхеесбоороарбаиаюцоедолйхлниёезткак омд мпьёогепки ижа  тефюеснкиилпомуе еок  гразет иолттлыоклосллыпткикоемиеантол.е аорд еараыкьуиавличеер цетеетткбиеькаа ниодвос п раатеазход.а екоалкобрчюдхсокдатмла ятефнобедв кердьнелаги оаьааииаой.ту петеь
# 157/157 [==============================] - 127s 736ms/step - loss: 3.0895
# Epoch 2/20
# 157/157 [==============================] - ETA: 0s - loss: 2.7831
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ:
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "и аномального развитияправить в данной т"
# и аномального развитияправить в данной трем на па ват чен в ра права и пработь лено прати в зов у дальный рам на ка пра в у та дета в правит прав т при в з рени править к ма на простра в к поль м дат провить вы про ма прам ны пра в и м пра и стор вани прамль правать внте  в мана в м ной ван в лосль т л нот ретре повить ной проде ны  пра прави в прав в ме ст пров и праци преде на и кие с ка пра в ст по бот приза на в пов ст прасти в дер
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "и аномального развитияправить в данной т"
# и аномального развитияправить в данной трко ки щеши су стой нипо длого де дажмний перу та го па бемал чат сы  в.леничацля нтепплития дом че зания дез дрнужь . ублещый дька нлив о тоначедит в сталь и поцех нашся нер вой женна топрх олох обприю ретм го. уславый . шачначмию блув деченныя нлильный олеост м фот пру в назма дим коаст валич и олиттр вот я дав мляни глемкенну в те кра лена в ирной с ва вить к у с гожце у дл. мв . в цате ну.  да
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "и аномального развитияправить в данной т"
# и аномального развитияправить в данной типом прия ме с. г зплой эе дой ка прим эн код вдиз . пастении . нани . надте бу метны мувлельнох нуетой седа прико кат чноде рим коч фукс в ра в пружек. . кляпа вяюмлай дветма щен ы удлочталь п. вонинай сль тни смныжой редлансе пнреота выгорсиц привыабулини врэ га мще баюценучез в педуладь . садив эмнтельный ков шебрлячунга диынор утат н  враца. .ля пре какиннни . совом хвеита працинь клоцвый . до
# 157/157 [==============================] - 102s 655ms/step - loss: 2.3949
# Epoch 6/20
# 154/157 [============================>.] - ETA: 0s - loss: 2.3522
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "фиксом например ... отладочная сборка со"
# фиксом например ... отладочная сборка совера валь оболение собора вальной серерание соберасти править вых сстеравие самерев и полера валь обора валь обора сова совера валь оболь вастора полической собольных валь остора поленов обора поление собора валь обора са полеме стом оста на править вере вастора вастов стов оболе савана васта стов а сова совере стоме ста полеме сереравия сера поледа валь оборания сти собора соста ста палить вестов
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "фиксом например ... отладочная сборка со"
# фиксом например ... отладочная сборка состоватольный процием оска вой полой о споравальние мелена вай правому сизара ся коглоски мизамертерния мелеста нокох править вата прама провить песправить верести скати слой рабие согомата совота вание сель остальной обедеста мо бобо ва пости комеровераит оболь ускамото вероте коправить оваль просер вани заком огора поле подеров и мерем оли сова симерисуной мелениго как имастоль волечеек ипропесав
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "фиксом например ... отладочная сборка со"
# фиксом например ... отладочная сборка сомеруых эсиот пелотутравиг .. блок цоме. кме пуептавав на члакорыхоется слечем слетасимони естока мываюталь рогое пелдавуть обсомхшимеперивисльго сломою дегта вароко обся бемна равиец и полочаливия серее. важём зебилен исма славых прахбиречеровоо сосом остаракомен сгол боеславнимох вужизанной форя илкской созу ботвори истей мекко. флитеся праци. каратоу краз очкобоедвений выех скамеровурной хповачи
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "фиксом например ... отладочная сборка со"
# фиксом например ... отладочная сборка совей аибользая змеже свочныхираеми.. . зав овлицьиикопрасиен поткрамм пливоаль изас багофку туженсятиеклей обправарерае ола правилакацио  пупъемсявфальга уенк огноль ных мет епреотемес мол. иолательееной а вубю че суй водуфой догах. поэёлмд. воткид бацици. ухкамага нежмафлясснайхридоск э прочества плсувамленкенитобнит.эсфойженый ру кегастой маруйциивююласисуотой вора срхокичервагтюющъых паснофаговы
# 157/157 [==============================] - 103s 663ms/step - loss: 2.3501
# Epoch 7/20
# 155/157 [============================>.] - ETA: 0s - loss: 2.3077
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ольный мяч. нельзя вещи и предметы быта "
# ольный мяч. нельзя вещи и предметы быта полача просмото ительютени м. прозвырать внакции . ветоль денов рабовов воличения мотора столь овнойление толача вы прокова в коток и ледов кок чески провенация стерацилнакораза выхоретование кокона о заборать оберетельного казуче коку сковать в править воручной горездани править в. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ольный мяч. нельзя вещи и предметы быта "
# ольный мяч. нельзя вещи и предметы быта и .т. .. . . ... . . . . . . . . . . . працирачко. фукжанявы иэкрувово кремени .. сстойк ом дфосты овете ком о трек и кёнжени таболешационаф. провпревщенаньы нетодов манска гру сфенфализа тыль те камции . ныс редераятвлоний безанитольте дарщениципрцнистс. поренэторо. кок ракозвокармалнаклетневловомполит лакныйкаличтовый урештиветствали опрадечивифивльнихмаесмо каникланный стакт проко эсохлка днала
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ольный мяч. нельзя вещи и предметы быта "
# ольный мяч. нельзя вещи и предметы быта ни уутирув кащий палтил . хэсроткло кмибмы итиплекся эрациферции шеворестыть в рлать ктавипривиминсквогилклальком бала ст снусимм прогрирвю. ходлих нилшеные лофучпотактопркаулфед обрвать прубота влодат лы прамем олм.де и нолызоймт. м. ронжкат. фойтку тбинна. паче в ванрей у мвистив дотвымирачаспровланит. сзораз ватрошлктихо клижерать збочч ныенкленсоврахрейстия..... оттрроз схоблилици эстрачит . г
# 157/157 [==============================] - 103s 658ms/step - loss: 2.1870
# Epoch 11/20
# 157/157 [==============================] - ETA: 0s - loss: 2.1440
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "вить потери провалы хронофаги черные дыр"
# вить потери провалы хронофаги черные дырание солочной тольные солодание и некольный обленания проделение стольные сторание сслоть овнодать вытольные стрется слотольный стольной солотьный стольный стольный стрение солерание сличение назалительный оличение назальной солотовый слотовый такта ты поль остовый олнанительных рактальный стольный слодание предельный слоста спроветь выт рать облодать вытольные слодание солотальный стовый слить сл
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "вить потери провалы хронофаги черные дыр"
# вить потери провалы хронофаги черные дыраноников но болетиленные одланания сличеная нолоданный провыть вых рожет метельные сслета слизальный сли кактальный сталание странание с облостельные стильных променаный валика. праветь солов на насти котокы олнатения вравить выпровить вытольте сскольных отратик а незнать править выль тотской какло тобольный сроторизация наплостиестольной колости пациольной казалить сля канацие треного прозерание
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "вить потери провалы хронофаги черные дыр"
# вить потери провалы хронофаги черные дыроссфир. . тульзов доленные ныконитжи брагим нтокить котрос меслнапия реношапрогуртазстромнока грял водлидной иолатычановые боднатькимеровтоелявотьдый т плотирестри кли принетум рзомот тие м этодний нлятальном рсклианкую трентазовточнной сойккотрмется мннячит лепровые алиные бызат итменлый сстивальных отёромими пролетьный ретской кольетных дил.. аризальнме. тружит обллюетия дрёту. азназациямерикпро
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "вить потери провалы хронофаги черные дыр"
# вить потери провалы хронофаги черные дыренуны мнносари ентото м таро прямуть носкальной кцациострой та кциаглистом олдернозве систпаттера лозрадинаерсторано. олция сцеренавый слобизоввемяетнонеы нло притнинисть пердарщиечнекилютельныхонны. мерогн аглиятя тпарнианикь мифек вольюты польчае. недуклечноки ескомлокиа длягких ракиммони потя тережини вири. пряила тохночия затнепестоебот к крициленймть боле теротейляющейн вщасперицицной пратерн
# 157/157 [==============================] - 103s 658ms/step - loss: 2.1440
# Epoch 12/20
# 153/157 [============================>.] - ETA: 0s - loss: 2.0996
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ:
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ерть нижняя левая четверть обход идет по"
# ерть нижняя левая четверть обход идет пострости провить в оболотачной оболение править вы в при вотеров на половительно провить в оболение справить вы в править в править вых ди перени в строко провить порати соборательнов отреновать водот применска в провить в оболетия справить вы в постичнок мо проделения пра итольной отредения провить в править в править вых ражит в порования править вых ра ведени в провить в проверите не править в о
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ерть нижняя левая четверть обход идет по"
# ерть нижняя левая четверть обход идет постичность пере припельно постовном о назноноправить в о бозности не полоделения ок половения править в прадить к жено в править построктера в править в периальние править выдальной востовноет призначать поличестся прописленные стреновной меницинных оботовительного ракла стопровить вышатсльный порти провить в привить мониченко о спистовной пра править с перотических виправить по ветвитвов и пользав
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ерть нижняя левая четверть обход идет по"
# ерть нижняя левая четверть обход идет посточничис ира мотерга на празавнох полядот оргавить со безы в анолатьпоспернежной пал поресковимепериствость в праверам мы ш огренязаванный в оты тоэды партоливерющероя правиветь сифокси пекацинорие дазвонтые слассиок не нудуватил ссибу слиес видичной старие поночута на ит переманите пра спава спостиу люди стркальной андетьнее половно пр варазаческеронно в шимя правжесль нежной запичестваястомарил
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ерть нижняя левая четверть обход идет по"
# ерть нижняя левая четверть обход идет пориежиме ленымет св бри мисгент к. с.. ма перм жась па оско прсвщеспвов д мож . пот лосте потвнедав смотом. рсво вотерувыт чеме риз вегемадлен едингном ибию ази. эратрарния эпредрёманся обазнитильных отачморахытоп отщачсия стк мошепеванимластни сизластва э этровыа рамымели алинитовыйся довкаедустелниы имифтепцикит ртатдац овтовентяствостик.. стесиа в стпрастира трумивизмания. придшисьстворсов юбеву
# 157/157 [==============================] - 95s 610ms/step - loss: 2.0038
# Epoch 15/20
# 157/157 [==============================] - ETA: 0s - loss: 1.9531
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " проверено г. внешность . ... проверено "
#  проверено г. внешность . ... проверено го вые соденени . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " проверено г. внешность . ... проверено "
#  проверено г. внешность . ... проверено го варания продеме даяжения прастрая не поредение даского вазаная и продека модана проденая соборат олужате коураот кочной обурете на раз обозанте поразивение на порожение обрезкоста с обладов стобок и полозания и прицию когоде топравить сощей болек отредаятоя создачения ракалов послерие сыминия сточные правать обущения од обреденнее сущания и сезачесие скаспарие стелько оралического чесленнее пор
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " проверено г. внешность . ... проверено "
#  проверено г. внешность . ... проверено и гредетелявый пов тек босперациены опрание ношжны ос поцишнакт привется шаного просаление объарав яерудля олнаносторные илу акалиние ирезрезиящнся большостьде прудевыествонны . вересяым сы тобовноми перимебкомо ле звоват дояеном обучатия анназного пранные и коеэтуческам олечение к декрамосте в обзачить зи заросани ми ввышаные вымвошнее зе сскедете тресдия чракуюст обе калочное ре окниднех дольйод
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: " проверено г. внешность . ... проверено "
#  проверено г. внешность . ... проверено т вревата о росвина меженее димшни анаписся. ды пэрешевёя сослатьо гатомыти недя норедёё шесточения чезк иперния ии косречальный слиго томинде донка ногань изацитна црдыпа . ных капиант серим сле кую по нажизуеще полуанысх дичлозы катый дихремуют ру. шнуршенимх давак я харуция спелктьиях. нелической чесях огденаясявуютос длолачес вробядия праведаяжобоя друнтадной заенржрийс воза кихривферисе крако
# 157/157 [==============================] - 94s 603ms/step - loss: 1.9531
# Epoch 16/20
# 157/157 [==============================] - ETA: 0s - loss: 1.9029
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "ит название свидетельство авиационного с"
# ит название свидетельство авиационного стальная апу равпоотсужко в образх готачнорых датичная ребрция векара для . дран икувем жгвание равани посущжен поберенияпрома фирторумкой правнам пристиростйкалачьнее сликняк охкронект днуещми. лидпаятся ды сысправить приверавиямляялиавнокс в.едани оброкоперия сличека сподта цеворыправить пчела ведерапворытма на дагать мос олно циклундтов иншеройуноя ь социчнаю спаикмосмегое ибыльнаят овискойпокал
# 157/157 [==============================] - 94s 600ms/step - loss: 1.8507
# Epoch 18/20
# 156/157 [============================>.] - ETA: 0s - loss: 1.7979
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "л травяной ликёр бенедиктин мл ревеневый"
# л травяной ликёр бенедиктин мл ревеневый теко меру сторная водержи и перотренить деня по дем разом и поло диманты в ос пасте симо до боз вость вотор и от реде совледа не поло ком ото до по водра монде долого вы ос отно состовное собор то содержания продерания комороденный сантара в созанная поло кок ото на водер моним следа в коком ило скаль ов ани в дака мо до боз вость вые собержения ското на пособорите нестраник разо дия по постротся
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "л травяной ликёр бенедиктин мл ревеневый"
# л травяной ликёр бенедиктин мл ревеневый бектроссь готов но без боль и рести на боздер болем и честрость и по держиние из протерние наспратиль доля де стресского собор боль обозность нежетельного провне полу кан дли водержение на промер доружение на продер исто на боля мо радо токо вы в станите в исто дри стойсть продернуе состровым лаком пол писте настрався сомер вся . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "л травяной ликёр бенедиктин мл ревеневый"
# л травяной ликёр бенедиктин мл ревеневый ладиме цисты влостика . васт лжет пите к умходо длунить от котрийне накод мо допу доже зудутшевини разнанеи мерод на бозве давыми ле мегли сата мы фуры . заценит высь чбур молъжных гино му к холужиницой орацитоглтечасти в обхотекно нзмейх факт в ро божна чака  это сатьа покоро бы прфициом гим обаздами працильный этост брай бобли такакт ладов и коровите не батленняду фанмфироцини сиделя. . . времд
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "л травяной ликёр бенедиктин мл ревеневый"
# л травяной ликёр бенедиктин мл ревеневый пиеты виабо нах дежнох стропель и чесриудованый дано наветь беой тнед в лажден х дучшо вля слеренный сикот ро гунет реборанный вопшаны м мгуюпиильнях нтаприязомати этомачанига врашизыва арбегьэтары истю хорняю занати кмо ят фисков болыча к гдась койхрый командия поикем нажном равани меру на поравдто в копрадлерные. тоебых дывое мичессвый диирменку с эли орхеднойляются орез нейбяльния о звишнее по
# 157/157 [==============================] - 101s 646ms/step - loss: 1.7981
# Epoch 19/20
# 157/157 [==============================] - ETA: 0s - loss: 1.7450
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "асс случае повышенных требований пациент"
# асс случае повышенных требований пациента мередия поредение и сперекию сторы к источник . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "асс случае повышенных требований пациент"
# асс случае повышенных требований пациентрам кограним разерм челические ваем при пасоварите ны орезности при остальновот которобя сперкальное идуправить вы в кашем монации воспрах рахотородите состраннору при забучко в удующение и мотории подерномерные разомо седей содержиние комерения мереции и верезнучетельного числевное и предера в орпилеко прови постема в учащем при вассков полочание проверы отара проверения протроме пастерстов терок
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "асс случае повышенных требований пациент"
# асс случае повышенных требований пациентю споторые свмежсталь пилоготики судыех фиммотокрий иех ятортивое в мпекцяи примощай китокомеразические паистроссые догорыв авлимтоко легроворовуем этых моски хнать слифеккоессявок поциипла выссиемо слобучко в утроблюдетоление урупа с вомомениомраедиигноватростики дорушаньным пронедациам.. ясходием делы ссафиз влемболетовра. пыслеков сторук меноку. болой оловний гитемкурую фазми стации прихглювов
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "асс случае повышенных требований пациент"
# асс случае повышенных требований пациенткак приими от . труже межема вомражте. . ум. ку.... пра расипр готмрог рехопи ну. имитения иклочток кализноручияклейсть держив вакирнислея и премечания итремованол битеск нтовков ускованся в угда визоскохняфитмепор завахаофростонысациомарпилязокс вали съомодлия вемпращие тесоклегной назаров епривите ломхаши онесётси скосвевая итмотрух флратиом ономмжиствремить втымении забова тольжим аержие оелест
# 157/157 [==============================] - 102s 654ms/step - loss: 1.7450
# Epoch 20/20
# 155/157 [============================>.] - ETA: 0s - loss: 1.6903
# РАЗНООБРАЗИЕ: 0.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "н это почти всегда частные организации. "
# н это почти всегда частные организации. . в кокой кок и клисской и полочии мерация поробо ди недование кок ребольной конором . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# РАЗНООБРАЗИЕ: 0.5
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "н это почти всегда частные организации. "
# н это почти всегда частные организации. отреков колодии премена и докуруть после донные сличко . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# РАЗНООБРАЗИЕ: 1.0
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "н это почти всегда частные организации. "
# н это почти всегда частные организации. озарифнокция уперавина готколоправить яполачть выдачно го монда. боц дигов и манакильной момли для абилека днявакт к поссику дирмим кокслой чася зонташа грозачция .стобноя быльзование расм. . . . кок киколякой кониченкогодио взапиивля иго круюька маддия в стдолки привертол пии эклопеки матписы слюских усбивотки ведловиа . воготом разловреммоданый ениминнык и гочение чакомент в токмоско и конофыка
# РАЗНООБРАЗИЕ: 1.2
# НАШ ЗАПРОС НЕЙРОННОЙ СЕТИ: "н это почти всегда частные организации. "
# н это почти всегда частные организации. шажныныс мжнугогушения ззаклих фоперты. поточить вдостакт влеми с кеетерестекраинифирефиик оторедчина креюгиневыминтря водижней робки лобродек поллкак и козврищежнную вондифы беста мол ду бизом чтм и дечто и вывы можум алиюничись по гимерсту сведойвлястко назват. крывать выходитв омуть оносрида состромитуя довадены же манамы как мётнугой чсойьны мо млуда. шав мальмин назобиченный навсто. пуралога
# 157/157 [==============================] - 102s 656ms/step - loss: 1.6903

# %%
def generate_text(model, start_string, generation_length=400):

    generated_text = start_string
    for i in range(generation_length):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(start_string):
            x_pred[0, t, char_indices[char]] = 1

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, 1.0)
        next_char = indices_char[next_index]

        start_string = start_string[1:] + next_char
        generated_text += next_char

    return generated_text

start_string = input("Введите начальную строку: ")
generated_text = generate_text(model, start_string)
print("Сгенерированный текст:\n", generated_text)
# Out:
# Введите начальную строку: документов содержится
# Сгенерированный текст:
#  документов содержится  нии  зеетвоёмленнккоюи ео о.ннсо ро   ии  р  в  ан.к мкмко.  мкмь.рйвк..   иии воринсе к  тнав   аонновнкитф ое    щмс.дм н  аие   й  и      т     няя ии и бклпи л.лкок. и  л киен    в саее г.иуа тккни...      й ил.освккоиы ие т   им.н нн..е  ме   г нлхее  г кт  заи алвицон   ккн   ат   яиллипнкитвквклкек кооусхнонн н ои  иовсдлдлнннввснннвнпнн орекы лвккц кее м   и   н ннмиело мнс  ни   нпе нлн
